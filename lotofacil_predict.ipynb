# %% [markdown]
# # 0. Imports

# %% [markdown]
# ## 0.0. Imports

# %%
import pandas as pd

# %% [markdown]
# ## 0.1. Helper Functions

# %%
dados = pd.read_excel('dados.xlsx')

# %% [markdown]
# ## 0.2. Load Data

# %%
dados = pd.read_csv('dados_lotofacil.csv')

# %%
#dados = dados.loc[~dados['Concurso'].isna()]
#dados = dados.loc[~dados['Bola1'].isna()]
#
#dados.to_csv(r'C:\Users\joaoh\repos\dados_lotofacil.csv', index=False)

# %% [markdown]
# # 1. Data Description

# %%
df1 = dados

# %%
df1.columns
# Out:
# Index(['Concurso', 'Data_Sorteio', 'Bola1', 'Bola2', 'Bola3', 'Bola4', 'Bola5',
#        'Bola6', 'Bola7', 'Bola8', 'Bola9', 'Bola10', 'Bola11', 'Bola12',
#        'Bola13', 'Bola14', 'Bola15', 'Arrecada=C3=A7=C3=A3o_Total',
#        'Ganhadores_15_N=C3=BAmeros', 'Cidade', 'Ganhadores_14_N=C3=BAmeros',
#        'Ganhadores_13_N=C3=BAmeros', 'Ganhadores_12_N=C3=BAmeros',
#        'Ganhadores_11_N=C3=BAmeros', 'Valor_Rateio_15_N=C3=BAmeros',
#        'Valor_Rateio_14_N=C3=BAmeros', 'Valor_Rateio_13_N=C3=BAmeros',
#        'Valor_Rateio_12_N=C3=BAmeros', 'Valor_Rateio_11_N=C3=BAmeros',
#        'Acumulado_15_N=C3=BAmeros', 'Estimativa_Pr=C3=AAmio',
#        'Valor_Acumulado_Especial'],
#       dtype='object')

# %%
cols_new = ['concurso', 'data_sorteio', 'bola1', 'bola2', 'bola3', 'bola4', 'bola5', 'bola6', 'bola7', 'bola8',
            'bola9', 'bola10', 'bola11', 'bola12', 'bola13', 'bola14', 'bola15', 'arrecadacao_total',
            'ganhadores_15_numeros', 'cidade', 'ganhadores_14_numeros', 'ganhadores_13_numeros', 'ganhadores_12_numeros',
            'ganhadores_11_numeros', 'valor_rateio_15_numeros', 'valor_rateio_14_numeros', 'valor_rateio_13_numeros',
            'valor_rateio_12_numeros', 'valor_rateio_11_numeros', 'acumulado_15_numeros', 'esimativa_premio',
            'valor_acumulado_especial']

# %%
df1.columns = cols_new

# %%
df1
# Out:
#       concurso data_sorteio  bola1  bola2  bola3 bola4  bola5  bola6  bola7  \
# 0            1   29/09/2003    2.0    3.0    5.0   006    9.0   10.0   11.0
# 1            2   06/10/2003    1.0    4.0    5.0   006    7.0    9.0   11.0
# 2            3   13/10/2003    1.0    4.0    6.0   007    8.0    9.0   10.0
# 3            4   20/10/2003    1.0    2.0    4.0   005    8.0   10.0   12.0
# 4            5   27/10/2003    1.0    2.0    4.0   008    9.0   11.0   12.0
# ...        ...          ...    ...    ...    ...   ...    ...    ...    ...
# 2553      2554   23/06/2022    2.0    3.0    4.0  008=   10.0   11.0   13.0
# 2554      2555   24/06/2022    2.0    3.0    4.0  006=    7.0    8.0   11.0
# 2555      2556   25/06/2022    1.0    2.0    5.0  010=   11.0   12.0   15.0
# 2556      2557   27/06/2022    2.0    3.0    4.0  005=    6.0    7.0    8.0
# 2557      2558   28/06/2022    3.0    4.0    5.0  006=   10.0   12.0   14.0
#
# ...
